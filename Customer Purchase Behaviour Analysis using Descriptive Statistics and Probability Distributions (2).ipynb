# %% [markdown]
# # Customer Purchase Behaviour Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
# importing libraries

# for numerical calculations
import numpy as np

# for data manipulation and analysis
import pandas as pd

# for data visualisation
import matplotlib.pyplot as plt

# for aesthetic and sophisticated data visualisation
import seaborn as sns

# for statistical information
from scipy import stats as st

# %%
# Load Dataset
path = '/content/Superstore Marketing Data.xlsx'

# creating a dataframe by reading the contents of file
superstore_df = pd.read_excel(path)

# %%
superstore_df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# Data types of all columns are fine . We can see null values in income column which we have to take care of. Since income column contains important data we will remove all the rows where income column has null values

# %%
superstore_df.dropna(subset=['Income'],inplace=True)
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2216 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2216 non-null   int64
#  1   Year_Birth           2216 non-null   int64
#  2   Education            2216 non-null   object
#  3   Marital_Status       2216 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2216 non-null   int64
#  6   Teenhome             2216 non-null   int64
#  7   Dt_Customer          2216 non-null   object
#  8   Recency              2216 non-null   int64
#  9   MntWines             2216 non-null   int64
#  10  MntFruits            2216 non-null   int64
#  11  MntMeatProducts      2216 non-null   int64
#  12  MntFishProducts      2216 non-null   int64
#  13  MntSweetProducts     2216 non-null   int64
#  14  MntGoldProds         2216 non-null   int64
# ...

# %% [markdown]
# We don't have any null values left. Now we will handle any outliers or inconsistencies in data

# %%
# finding information of values in Dt_Customer_column
superstore_df['Dt_Customer'].value_counts()
# Out:
# ########      905
# 8/31/2012      12
# 2/14/2013      11
# 5/22/2014      10
# 8/20/2013      10
#              ...
# 5/27/2013       1
# 10/19/2012      1
# 3/28/2014       1
# 6/13/2014       1
# 5/25/2013       1
# Name: Dt_Customer, Length: 400, dtype: int64

# %% [markdown]
# Since we have high number of ####### values in it we will remove this column

# %%
superstore_df.drop(columns=['Dt_Customer'],inplace=True)
superstore_df.columns
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
#        'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# We have successfully removed Dt_Customer column as seen in the names of columns . Now we will analyse other columns for any anomaly.

# %%
# analysing Year_Birth column
superstore_df.Year_Birth.value_counts()
# Out:
# 1976    89
# 1971    86
# 1975    83
# 1972    78
# 1978    76
# 1970    75
# 1965    74
# 1973    72
# 1969    70
# 1974    69
# 1956    55
# 1979    53
# 1952    52
# 1977    52
# 1958    52
# 1968    51
# 1959    50
# 1966    50
# 1960    49
# 1954    49
# 1955    48
# 1982    44
# 1967    44
# 1963    44
# 1962    44
# 1951    42
# 1986    41
# 1983    41
# 1957    41
# 1964    41
# 1980    39
# 1984    38
# 1981    38
# 1961    35
# 1953    35
# 1985    32
# 1949    30
# 1989    29
# 1950    29
# 1988    29
# 1987    27
# 1948    21
# 1990    18
# 1947    16
# 1946    16
# 1991    15
# 1992    13
# 1945     8
# 1944     7
# 1943     6
# 1993     5
# 1995     5
# 1994     3
# 1996     2
# 1893     1
# 1899     1
# 1941     1
# 1940     1
# 1900     1
# Name: Year_Birth, dtype: int64

# %% [markdown]
# We will remove any date of birth less than 1940 from our data as they are outliers

# %%
# removing required rows
superstore_df=superstore_df[superstore_df['Year_Birth']>1940]

# checking whether any value left less than 1940
superstore_df.Year_Birth[superstore_df['Year_Birth']<1940]
# Out:
# Series([], Name: Year_Birth, dtype: int64)

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2212 entries, 0 to 2239
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2212 non-null   int64
#  1   Year_Birth           2212 non-null   int64
#  2   Education            2212 non-null   object
#  3   Marital_Status       2212 non-null   object
#  4   Income               2212 non-null   float64
#  5   Kidhome              2212 non-null   int64
#  6   Teenhome             2212 non-null   int64
#  7   Recency              2212 non-null   int64
#  8   MntWines             2212 non-null   int64
#  9   MntFruits            2212 non-null   int64
#  10  MntMeatProducts      2212 non-null   int64
#  11  MntFishProducts      2212 non-null   int64
#  12  MntSweetProducts     2212 non-null   int64
#  13  MntGoldProds         2212 non-null   int64
#  14  NumDealsPurchases    2212 non-null   int64
# ...

# %% [markdown]
# No row now have Year_Birth less than 1940

# %%
superstore_df.Marital_Status.value_counts()
# Out:
# Married     857
# Together    572
# Single      469
# Divorced    231
# Widow        76
# Alone         3
# YOLO          2
# Absurd        2
# Name: Marital_Status, dtype: int64

# %% [markdown]
# Removing alone,YOLO,absurd marital status from our data as they don't represent any marital type

# %%
superstore_df = superstore_df[superstore_df['Marital_Status'].str.contains("Alone|YOLO|Absurd")==False]
superstore_df.Marital_Status.value_counts()
# Out:
# Married     857
# Together    572
# Single      469
# Divorced    231
# Widow        76
# Name: Marital_Status, dtype: int64

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2205 entries, 0 to 2239
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2205 non-null   int64
#  1   Year_Birth           2205 non-null   int64
#  2   Education            2205 non-null   object
#  3   Marital_Status       2205 non-null   object
#  4   Income               2205 non-null   float64
#  5   Kidhome              2205 non-null   int64
#  6   Teenhome             2205 non-null   int64
#  7   Recency              2205 non-null   int64
#  8   MntWines             2205 non-null   int64
#  9   MntFruits            2205 non-null   int64
#  10  MntMeatProducts      2205 non-null   int64
#  11  MntFishProducts      2205 non-null   int64
#  12  MntSweetProducts     2205 non-null   int64
#  13  MntGoldProds         2205 non-null   int64
#  14  NumDealsPurchases    2205 non-null   int64
# ...

# %% [markdown]
# Now there is no anomaly in marital status

# %%
superstore_df = superstore_df[superstore_df["Income"]<150000]

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2197 entries, 0 to 2239
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2197 non-null   int64
#  1   Year_Birth           2197 non-null   int64
#  2   Education            2197 non-null   object
#  3   Marital_Status       2197 non-null   object
#  4   Income               2197 non-null   float64
#  5   Kidhome              2197 non-null   int64
#  6   Teenhome             2197 non-null   int64
#  7   Recency              2197 non-null   int64
#  8   MntWines             2197 non-null   int64
#  9   MntFruits            2197 non-null   int64
#  10  MntMeatProducts      2197 non-null   int64
#  11  MntFishProducts      2197 non-null   int64
#  12  MntSweetProducts     2197 non-null   int64
#  13  MntGoldProds         2197 non-null   int64
#  14  NumDealsPurchases    2197 non-null   int64
# ...

# %% [markdown]
# We found some anomaly in Income values so we removed the outliers which were far different from other values

# %% [markdown]
# ##**Steps Taken to Clean Data**

# %% [markdown]
# 1 - Income being an important variable we have removed all rows containing null values in it using the 'dropna' function.
#
# 2 - We have removed the dt_customer column as it contained a large number of non analysable values. We have used 'drop' function for it
#
# 3 - Marital status variable contained values (absurd,alone,YOLO) which have no meaning as far as marital status is concerned . We have removed rows containing such values. We have created a new dataframe devoid of these values and stored it our original superstore dataframe 'superstore_df'
#
# 4 - Year_Birth column contained years which are far different from other years. We have removed them by creating a new dataframe devoid of these values and stored this dataframe in our original superstore dataframe
#
# 5 - Income column had a some values far greater than other values so we removed that value by creating a new data frame devoid of that value and storing that dataframe in our original superstore dataframe.
#
# We did'nt find any other anomaly in our data.

# %% [markdown]
# ##**Customer Demographics Visualisation**

# %%
# creating a new age column

superstore_df['age'] = 2023 - superstore_df['Year_Birth']
superstore_df['age']
# Out:
# 0       53
# 1       62
# 2       65
# 3       56
# 4       34
#         ..
# 2235    47
# 2236    46
# 2237    47
# 2238    45
# 2239    54
# Name: age, Length: 2197, dtype: int64

# %%
sns.countplot(data = superstore_df , x = "Marital_Status")
plt.xlabel("Marital Status")
plt.ylabel("Number of Customers")
plt.title("Marital Status of Customers")
plt.show()

# %% [markdown]
# From this plot we can see most of our customers are married followed by customers who are living together with their partners without getting married

# %%
sns.countplot(data = superstore_df , x = "Education")
plt.xlabel("Education Status")
plt.ylabel("Number of Customers")
plt.title("Education Status of Customers")
plt.show()

# %% [markdown]
# From this plot we can see that most of our customers are only graduate followed by PHDs and master degree holders.

# %%
sns.histplot(data = superstore_df,x="age",kde=True)
plt.xlabel("Age(Years)")
plt.ylabel("Number of customers")
plt.title("Age Status of Customers")
plt.show()

# %% [markdown]
# Through this plot we can see most of our customers are in the age range of 40-70 years

# %%
sns.histplot(data = superstore_df,x = "Income")
plt.xlabel("Income of Customers($)")
plt.ylabel("Number of Customers")
plt.title("Income Status of Customers")
plt.show()

# %% [markdown]
# Here we found that most of our customers have income in the range of 30K-80k dollars

# %%
superstore_df.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2197.000000  2197.000000    2197.000000  2197.000000  2197.000000
# mean    5588.219390  1968.902594   51617.030496     0.442421     0.506600
# std     3244.695216    11.686423   20732.943191     0.537300     0.544535
# min        0.000000  1941.000000    1730.000000     0.000000     0.000000
# 25%     2826.000000  1959.000000   35178.000000     0.000000     0.000000
# 50%     5455.000000  1970.000000   51315.000000     0.000000     0.000000
# 75%     8420.000000  1977.000000   68316.000000     1.000000     1.000000
# max    11191.000000  1996.000000  113734.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2197.000000  2197.000000  2197.000000      2197.000000
# mean     49.051434   306.345016    26.414201       165.544834
# std      28.921138   337.915503    39.795785       217.946818
# ...

# %% [markdown]
# Describe function in pandas is used to get the various measures like mean, standard deviation , minimum , maximum etc of all the numerical variables in the data. Some facts about our customers we got from this data-
#
# 1- Average Income - 51617 dollars
#
# 2- Middle 50 percentile income range -  35178-68316 dollars
#
# 3- Average Age - 54 years
#
# 4- Middle 50 percentile age range -  46-64 years

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# Outliers are values which fall outside the range = (mean - 3(standard deviation), mean + 3(standard deviation))

# %% [markdown]
# **Income Variable**

# %%
mean = np.mean(superstore_df.Income)
median = np.median(superstore_df.Income)
mode = st.mode(superstore_df.Income)
variance = np.var(superstore_df.Income)
standard_deviation = np.std(superstore_df.Income)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 51617.03049613109
# Median is 51315.0
# Mode is ModeResult(mode=7500.0, count=12)
# Variance is 429659277.9358019
# Standard deviation is 20728.224186741176

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["Income"]<lb) | (superstore_df["Income"]>ub)]
# Out:
# Empty DataFrame
# Columns: [Id, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain, age]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# No outliers in Income variable

# %% [markdown]
# **Recency Variable**

# %%
mean = np.mean(superstore_df.Recency)
median = np.median(superstore_df.Recency)
mode = st.mode(superstore_df.Recency)
variance = np.var(superstore_df.Recency)
standard_deviation = np.std(superstore_df.Recency)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 49.05143377332726
# Median is 49.0
# Mode is ModeResult(mode=56, count=37)
# Variance is 836.0515193371026
# Standard deviation is 28.9145554926425

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["Recency"]<lb) | (superstore_df["Recency"]>ub)]
# Out:
# Empty DataFrame
# Columns: [Id, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, Response, Complain, age]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# No outliers in Recency variable

# %% [markdown]
# **MntWines Variable**

# %%
mean = np.mean(superstore_df.MntWines)
median = np.median(superstore_df.MntWines )
mode = st.mode(superstore_df.MntWines )
variance = np.var(superstore_df.MntWines )
standard_deviation = np.std(superstore_df.MntWines)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 306.3450159308147
# Median is 177.0
# Mode is ModeResult(mode=2, count=41)
# Variance is 114134.91328080313
# Standard deviation is 337.83859057366897

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["MntWines"]<lb) | (superstore_df["MntWines"]>ub)]
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 196    3009        1962         PhD          Widow  71670.0        0
# 222    5547        1982         PhD        Married  84169.0        0
# 223    8362        1982         PhD        Married  84169.0        0
# 472    9260        1945         PhD        Married  70356.0        0
# 924    7431        1991         PhD         Single  68126.0        0
# 1026   4580        1969  Graduation        Married  75759.0        0
# 1293    737        1949         PhD        Married  80360.0        0
# 1376   1103        1976      Master        Married  81929.0        1
# 1385   3174        1959  Graduation       Together  87771.0        0
# 1386   5536        1959  Graduation       Together  87771.0        0
# 1596   1665        1964         PhD       Divorced  64140.0        0
# 1661   4943        1953  Graduation        Married  70503.0        0
# 1885  11088        1971         PhD       Together  78642.0        0
# ...

# %% [markdown]
# We got some outliers. Now we have to remove them

# %%
# removing outliers from superstore dataframe
superstore_df = superstore_df[(superstore_df["MntWines"]>=lb) & (superstore_df["MntWines"]<=ub)]

# %% [markdown]
# **MntFruits Variable**

# %%
mean = np.mean(superstore_df.MntFruits)
median = np.median(superstore_df.MntFruits)
mode = st.mode(superstore_df.MntFruits)
variance = np.var(superstore_df.MntFruits)
standard_deviation = np.std(superstore_df.MntFruits)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 26.378093492208983
# Median is 8.0
# Mode is ModeResult(mode=0, count=389)
# Variance is 1589.085734587043
# Standard deviation is 39.863338226834976

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["MntFruits"]<lb) | (superstore_df["MntFruits"]>ub)]
# Out:
#          Id  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 29     9687        1975  Graduation         Single   73170.0        0
# 45     9595        1961  Graduation       Together   64260.0        0
# 101   10676        1982  Graduation        Married   63211.0        0
# 142   10089        1974  Graduation       Divorced  102692.0        0
# 190    9529        1990  Graduation        Married   73687.0        0
# ...     ...         ...         ...            ...       ...      ...
# 1922   2712        1956  Graduation        Married   71866.0        0
# 1959   3010        1989      Master       Together   88420.0        0
# 1962   1137        1964  Graduation         Single   81246.0        0
# 1982   7274        1957  Graduation        Married   78618.0        0
# 2190   8602        1964  Graduation       Divorced   69932.0        0
#
#       Teenhome  Recency  MntWines  MntFruits  ...  MntSweetProducts  \
# ...

# %% [markdown]
# We got some outliers. Now we have to remove them

# %%
# removing outliers from superstore dataframe
superstore_df = superstore_df[(superstore_df["MntFruits"]>=lb) & (superstore_df["MntFruits"]<=ub)]

# %% [markdown]
# **MntMeatProducts Variable**

# %%
mean = np.mean(superstore_df.MntMeatProducts)
median = np.median(superstore_df.MntMeatProducts)
mode = st.mode(superstore_df.MntMeatProducts)
variance = np.var(superstore_df.MntMeatProducts)
standard_deviation = np.std(superstore_df.MntMeatProducts)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 156.85882908404156
# Median is 62.0
# Mode is ModeResult(mode=7, count=52)
# Variance is 45253.01359296324
# Standard deviation is 212.72755720160762

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["MntMeatProducts"]<lb) | (superstore_df["MntMeatProducts"]>ub)]
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 53     1619        1956  Graduation        Married  90369.0        0
# 135    7233        1972  Graduation        Married  69209.0        0
# 208    5331        1977  Graduation        Married  74985.0        0
# 240   10150        1961  Graduation         Single  86429.0        0
# 308    1891        1980      Master       Divorced  78789.0        0
# 361    9493        1980         PhD         Single  76412.0        0
# 385    6072        1970      Master         Single  75345.0        0
# 491    8643        1971  Graduation       Together  69930.0        0
# 574    1592        1970  Graduation        Married  90765.0        0
# 671    5735        1991      Master         Single  90638.0        0
# 672    5350        1991      Master         Single  90638.0        0
# 687   10619        1994  Graduation         Single  95529.0        0
# 724     477        1986  Graduation        Married  83512.0        0
# ...

# %% [markdown]
# We got some outliers. Now we have to remove them

# %%
superstore_df = superstore_df[(superstore_df["MntMeatProducts"]>=lb) & (superstore_df["MntMeatProducts"]<=ub)]

# %% [markdown]
# **MntFishProducts Variable**

# %%
mean = np.mean(superstore_df.MntFishProducts)
median = np.median(superstore_df.MntFishProducts)
mode = st.mode(superstore_df.MntFishProducts)
variance = np.var(superstore_df.MntFishProducts)
standard_deviation = np.std(superstore_df.MntFishProducts)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 33.4137264378927
# Median is 11.0
# Mode is ModeResult(mode=0, count=370)
# Variance is 2518.0637265196538
# Standard deviation is 50.180312140516364

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["MntFishProducts"]<lb) | (superstore_df["MntFishProducts"]>ub)]
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 5      7348        1958         PhD         Single  71691.0        0
# 51     1402        1954      Master        Married  66991.0        0
# 70     1772        1975         PhD        Married  79174.0        0
# 169    7342        1961    2n Cycle          Widow  59184.0        0
# 285    4828        1954  Graduation       Divorced  79865.0        0
# 330    5302        1986  Graduation       Together  78394.0        0
# 340    1577        1946  Graduation        Married  78569.0        0
# 435    9369        1979    2n Cycle         Single  88194.0        0
# 575    4310        1944  Graduation        Married  80589.0        0
# 607    5453        1956      Master        Married  90226.0        0
# 614    3091        1981    2n Cycle       Together  75774.0        1
# 615     762        1981    2n Cycle       Together  75774.0        1
# 652   10736        1971  Graduation         Single  72258.0        0
# ...

# %% [markdown]
# We have some outliers to remove

# %%
# removing outliers
superstore_df = superstore_df[(superstore_df["MntFishProducts"]>=lb) & (superstore_df["MntFishProducts"]<=ub)]

# %% [markdown]
# **MntSweetProducts Variable**

# %%
mean = np.mean(superstore_df.MntSweetProducts)
median = np.median(superstore_df.MntSweetProducts)
mode = st.mode(superstore_df.MntSweetProducts)
variance = np.var(superstore_df.MntSweetProducts)
standard_deviation = np.std(superstore_df.MntSweetProducts)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 22.916295195641407
# Median is 7.0
# Mode is ModeResult(mode=0, count=399)
# Variance is 1342.9949746845289
# Standard deviation is 36.646895839682365

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["MntSweetProducts"]<lb) | (superstore_df["MntSweetProducts"]>ub)]
# Out:
#         Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0     1826        1970  Graduation       Divorced  84835.0        0         0
# 31    9264        1986  Graduation        Married  79529.0        0         0
# 39    3767        1968  Graduation        Married  61314.0        0         1
# 42    1524        1983    2n Cycle         Single  81698.0        0         0
# 71    5341        1962    2n Cycle       Divorced  81975.0        0         1
# ...    ...         ...         ...            ...      ...      ...       ...
# 2105  8204        1971    2n Cycle        Married  78041.0        0         0
# 2129  6055        1979  Graduation        Married  71626.0        0         0
# 2175  5748        1965  Graduation        Married  59754.0        0         1
# 2185  5046        1958  Graduation       Divorced  78331.0        0         1
# 2238   528        1978  Graduation        Married  65819.0        0         0
#
# ...

# %% [markdown]
# We have to remove some outliers

# %%
superstore_df = superstore_df[(superstore_df["MntSweetProducts"]>=lb) & (superstore_df["MntSweetProducts"]<=ub)]

# %% [markdown]
# **MntGoldProds Variable**

# %%
mean = np.mean(superstore_df.MntGoldProds)
median = np.median(superstore_df.MntGoldProds)
mode = st.mode(superstore_df.MntGoldProds)
variance = np.var(superstore_df.MntGoldProds)
standard_deviation = np.std(superstore_df.MntGoldProds)

print("Mean is",mean)
print("Median is",median)
print("Mode is",mode)
print("Variance is",variance)
print("Standard deviation is",standard_deviation)
# Out:
# Mean is 38.803580562659846
# Median is 20.0
# Mode is ModeResult(mode=4, count=68)
# Variance is 2246.027915568318
# Standard deviation is 47.39227696121297

# %%
lb = mean - 3*standard_deviation
ub = mean + 3*standard_deviation

# checking whether any value is an outlier
superstore_df[(superstore_df["MntGoldProds"]<lb) | (superstore_df["MntGoldProds"]>ub)]
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 14    10311        1969  Graduation        Married   4428.0        0
# 60     4246        1982      Master         Single   6560.0        0
# 163   10814        1947  Graduation       Together  70321.0        0
# 370    3766        1959      Master          Widow  33051.0        0
# 403   11101        1991  Graduation       Together  89891.0        0
# 404    9212        1962      Master        Married  72828.0        0
# 410     380        1954  Graduation       Divorced  64497.0        0
# 486    6721        1951  Graduation        Married  71965.0        0
# 535   11112        1966  Graduation       Together  70713.0        0
# 585    9984        1981    2n Cycle        Married  56337.0        1
# 639   10343        1991    2n Cycle         Single  61618.0        0
# 658    6299        1968         PhD       Divorced  42564.0        0
# 678   10524        1963      Master       Divorced  49476.0        0
# ...

# %% [markdown]
# We have some outliers to remove

# %%
superstore_df = superstore_df[(superstore_df["MntGoldProds"]>=lb) & (superstore_df["MntGoldProds"]<=ub)]

# %% [markdown]
# We have found statistical information of all the key variables of data and removed outliers if necessary . Now we proceed towards the next task

# %%
# information about the data after removing outliers
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1905 entries, 1 to 2237
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1905 non-null   int64
#  1   Year_Birth           1905 non-null   int64
#  2   Education            1905 non-null   object
#  3   Marital_Status       1905 non-null   object
#  4   Income               1905 non-null   float64
#  5   Kidhome              1905 non-null   int64
#  6   Teenhome             1905 non-null   int64
#  7   Recency              1905 non-null   int64
#  8   MntWines             1905 non-null   int64
#  9   MntFruits            1905 non-null   int64
#  10  MntMeatProducts      1905 non-null   int64
#  11  MntFishProducts      1905 non-null   int64
#  12  MntSweetProducts     1905 non-null   int64
#  13  MntGoldProds         1905 non-null   int64
#  14  NumDealsPurchases    1905 non-null   int64
# ...

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %% [markdown]
# 1 - Variables that could follow binomial distribution - 'Kidhome', 'Teenhome','Complain','Response'
#
# 2 - Variables that could follow normal distribution - 'MntWines', 'MntFruits', 'MntMeatProducts','MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'Income'
#
#
# Now we will find probabilities and expected values for these variables

# %% [markdown]
# #**Binomial Distribution**

# %% [markdown]
# Binomial probability distribution is the probability distribution showing the probability of given number of successes in a fixed number of independent trials .In binomial distribution first we will find success probabilities related to variables and create a formula. After inserting any values in the formula we may get our probability

# %% [markdown]
# **Kidhome Variable**

# %% [markdown]
# First we will find probability of success in each event. Here success is customers having a kids home and failure is not having one.
#
# Success probability = total number of customers having atleast one kid home /
#                       total number of customers

# %%
# finding kid homes count of customers
superstore_df.Kidhome.value_counts()
# Out:
# 0    993
# 1    866
# 2     46
# Name: Kidhome, dtype: int64

# %%
success_prob = (866+46)/(993+866+46)
round(success_prob,3)
# Out:
# 0.479

# %% [markdown]
# We got our success probability . Now we will create a python code using stats function of scipy library to find our required probabilty

# %% [markdown]
# Formula = st.binom.pmf(k,n,p)
#
# where
#
# k = number of customers having kid home
#
# n = total number of customers
#
# p = probability of customer having atleast 1 kid home
#
# here p = 0.479
#
# Now we can put any value for k and n provided k<=n
#
# Lets take an example
#
# k = 5
#
# n = 10
#
# Here we will find what is the probability of 5 customers from a total of 10 customers of the company having atleast 1 kid home

# %%
prob = st.binom.pmf(5,10,0.479)
prob
# Out:
# 0.24393084731812104

# %% [markdown]
# Here we found our probabilty as 0.243. Now we plot a line graph to show distribution of probabilities for different values of k and n = total number of customers.

# %%
n = 1905
k_values = list(range(n+1))
p = 0.479
probabilities = [st.binom.pmf(k,n,p) for k in k_values]
sns.lineplot(x = k_values,y = probabilities)
plt.show()

# %% [markdown]
# The graph shows probability increasing sharply after 750 customers and decreasing sharply before 1000 customers

# %%
expected_value = st.binom.mean(n,p)
expected_value
# Out:
# 912.495

# %% [markdown]
# Our expected value is 912.495 for Kidhome variable

# %% [markdown]
# **Teenhome Variable**

# %% [markdown]
# First we will find probability of success in each event. Here success is customers having a teen home and failure is not having one.
#
# Success probability = total number of customers having atleast one teen home / total number of customers

# %%
superstore_df.Teenhome.value_counts()
# Out:
# 1    939
# 0    920
# 2     46
# Name: Teenhome, dtype: int64

# %%
success_prob = (939+46)/(939+46+920)
round(success_prob,3)
# Out:
# 0.517

# %% [markdown]
# Same code will be used for Teenhome variable
#
# Formula = st.binom.pmf(k,n,p)
#
# where
#
# k = number of customers having teen home
#
# n = total number of customers
#
# p = probability of customer having atleast 1 teen home
#
# here p = 0.479
#
# Now we can put any value for k and n provided k<=n
#
# Example -
#
# k=6 , n = 15

# %%
k = 6
n = 15
p = 0.517
prob = st.binom.pmf(k,n,p)
prob
# Out:
# 0.13673242528384988

# %% [markdown]
# We can use our formula like used above. Now we will plot a line graph to show variation of probabilities with different k values

# %%
n = 1905
k_values = list(range(n+1))
p = 0.517
probabilities = [st.binom.pmf(k,n,p) for k in k_values]
sns.lineplot(x = k_values , y = probabilities)
plt.show()

# %% [markdown]
# Here we find probabilities increasing sharply before k = 1000 and decreasing sharply after 1000

# %%
expected_value = st.binom.mean(n,p)
expected_value
# Out:
# 984.885

# %% [markdown]
# Our expected value is 984.885

# %% [markdown]
# **Complain Variable**

# %% [markdown]
# Here success is customer making a complaint in the last two years
#
# success probability = number of customers making a complaint in last 2 years/
#                       total number of customers

# %%
superstore_df.Complain.value_counts()
# Out:
# 0    1885
# 1      20
# Name: Complain, dtype: int64

# %%
success_prob = 20/(1885+20)
round(success_prob,3)
# Out:
# 0.01

# %% [markdown]
# Formula = st.binom.pmf(k,n,p)
#
# k = number of customers making complaint
#
# n = total customers
#
# p = probability of customer making complaint
#
# (k<=n)
#
# example -
#
# k = 10
#
# n = 25
#
# We will find probability for such scenario

# %%
k = 10
n = 25
p = 0.01
prob = st.binom.pmf(k,n,p)
prob
# Out:
# 2.811324347317257e-14

# %% [markdown]
# We will now plot a line graph to show variation of probabilities with values of k

# %%
n = 1905
k_values = list(range(n+1))
probabilities = [st.binom.pmf(k,n,p) for k in k_values]
sns.lineplot(x = k_values , y = probabilities)
plt.show()

# %% [markdown]
# Here we see inflection near k = 0

# %%
expected_value = st.binom.mean(n,p)
expected_value
# Out:
# 19.05

# %% [markdown]
# Our expected value is 19.05

# %% [markdown]
# **Response Variable**

# %% [markdown]
# Here success is when customer accepted the company's offer in last campaign.
#
# Probability of success = number of customers accepting company's offer/
#                          total number of customers

# %%
superstore_df.Response.value_counts()
# Out:
# 0    1662
# 1     243
# Name: Response, dtype: int64

# %%
success_prob = 243/(1662+243)
round(success_prob,2)
# Out:
# 0.13

# %% [markdown]
# Formula = st.binom.pmf(k,n,p)
#
# k = number of customers accepting offer
#
# n = total customers
#
# p = probability of customer accepting offer
#
# (k<=n)
#
# example -
#
# k = 9
#
# n = 17
#
# We will find probability for such scenario

# %%
k = 9
n = 17
p = 0.13

prob = st.binom.pmf(k,n,p)
prob
# Out:
# 8.461145250649781e-05

# %% [markdown]
# Now we plot a line graph to show variation of probabilities with values of k

# %%
n = 1905
p = 0.13
k_values = list(range(n+1))
probabilities = [st.binom.pmf(k,n,p) for k in k_values]
sns.lineplot(x = k_values , y = probabilities )
plt.show()

# %% [markdown]
# Here we see an inflection point near 250

# %%
expected_value = st.binom.mean(n,p)
expected_value
# Out:
# 247.65

# %% [markdown]
# Expected value is 247.65

# %% [markdown]
# #**Normal Distribution**

# %% [markdown]
# Normal distribution is a continuous distribution which is symmetric around the mean of the numeric data i.e. it has zero skewness. We have considered some variables as following normal distributions. We will find their related probabilities and expected values. Expected value is nothing but mean of the distribution

# %% [markdown]
# **Income Variable**

# %% [markdown]
# Formula = st.norm.cdf(k,loc=mean,scale=std)
#
# k = finding probability of getting any value less than this value
#
# loc = mean of distribution
#
# scale = standard deviation

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.Income)
std = np.std(superstore_df.Income)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 48175.5343832021
# standard deviation is 19298.08587187105

# %% [markdown]
# Lets take an example of k = 40000

# %%
# finding probability

k = 40000
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 40000 is {prob}")
# Out:
# Probability of getting any value less than 40000 is 0.3359124265259025

# %% [markdown]
# Plotting a graph for different values of k

# %%
# maximum value of income variable
n = int(max(superstore_df.Income))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Income")
plt.ylabel("Probabilities of less than income values")
plt.show()

# %% [markdown]
# Probabilities increasing sharply for income values 20000 - 80000 and after that normalising

# %% [markdown]
# **MntWines Variable**

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.MntWines)
std = np.std(superstore_df.MntWines)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 264.13438320209974
# standard deviation is 317.1560100282832

# %% [markdown]
# Lets take an example of k = 270

# %%
# finding probability

k = 270
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 270 is {prob}")
# Out:
# Probability of getting any value less than 270 is 0.507377785931022

# %% [markdown]
# Plotting a graph for different values of k

# %%
n = int(max(superstore_df.MntWines))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Amount spent on Wines")
plt.ylabel("Probabilities of less than Wine spending values")
plt.show()

# %% [markdown]
# Probabilities increasing sharply and then normalising near 1000

# %% [markdown]
# **MntFruits Variable**

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.MntFruits)
std = np.std(superstore_df.MntFruits)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 18.329133858267717
# standard deviation is 28.06949225249347

# %% [markdown]
# Lets take an example of k = 10

# %%
# finding probability

k = 10
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 10 is {prob}")
# Out:
# Probability of getting any value less than 10 is 0.38333532708414997

# %% [markdown]
# Plotting a graph for different values of k

# %%
n = int(max(superstore_df.MntFruits))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Amount spent on Fruits")
plt.ylabel("Probabilities of less than Fruit spending values")
plt.show()

# %% [markdown]
# Probabilities increasing sharply and normalising near 60

# %% [markdown]
# **MntMeatProducts Variable**

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.MntMeatProducts)
std = np.std(superstore_df.MntMeatProducts)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 121.04304461942257
# standard deviation is 166.28697401544486

# %% [markdown]
# Lets take an example of k = 130

# %%
# finding probability

k = 130
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 130 is {prob}")
# Out:
# Probability of getting any value less than 130 is 0.5214784174048972

# %% [markdown]
# Plotting a graph for different values of k

# %%
n = int(max(superstore_df.MntMeatProducts))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Amount spent on Meat Products")
plt.ylabel("Probabilities of less than Meat spending values")
plt.show()

# %% [markdown]
# Probabilities increases sharply before normalising near 400

# %% [markdown]
# **MntFishProducts Variable**

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.MntFishProducts)
std = np.std(superstore_df.MntFishProducts)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 26.145931758530185
# standard deviation is 38.75022262891684

# %% [markdown]
# Lets take an example of k = 30

# %%
# finding probability

k = 30
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 30 is {prob}")
# Out:
# Probability of getting any value less than 30 is 0.5396131810477959

# %% [markdown]
# Plotting a graph for different values of k

# %%
n = int(max(superstore_df.MntFishProducts))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Amount spent on Fish Products")
plt.ylabel("Probabilities of less than Fish products spending values")
plt.show()

# %% [markdown]
# Probabilities increases sharply before stabilising near 100

# %% [markdown]
# **MntSweetProducts Variable**

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.MntSweetProducts)
std = np.std(superstore_df.MntSweetProducts)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 18.205774278215223
# standard deviation is 26.992575400704137

# %% [markdown]
# Lets take an example of k = 25

# %%
# finding probability

k = 25
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 25 is {prob}")
# Out:
# Probability of getting any value less than 25 is 0.5993663064250663

# %% [markdown]
# Plotting a graph for different values of k

# %%
n = int(max(superstore_df.MntSweetProducts))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Amount spent on Sweet Products")
plt.ylabel("Probabilities of less than Sweet products spending values")
plt.show()

# %% [markdown]
# Probabilities increases sharply before stabilising near 60

# %% [markdown]
# **MntGoldProds Variable**

# %%
# finding mean and standard deviation
mean = np.mean(superstore_df.MntGoldProds)
std = np.std(superstore_df.MntGoldProds)

print(f"mean(expected value) is {mean}")
print(f"standard deviation is {std}")
# Out:
# mean(expected value) is 34.29396325459317
# standard deviation is 38.58243640898334

# %% [markdown]
# Lets take an example of k = 29

# %%
# finding probability

k = 29
prob = st.norm.cdf(k,loc=mean,scale=std)
print(f"Probability of getting any value less than 29 is {prob}")
# Out:
# Probability of getting any value less than 29 is 0.44543171553144906

# %% [markdown]
# Plotting a graph for different values of k

# %%
n = int(max(superstore_df.MntGoldProds))
k_values = list(range(n+1))
probabilities = [st.norm.cdf(k,loc=mean,scale=std) for k in k_values]
sns.lineplot(x = k_values, y = probabilities)
plt.xlabel("Amount spent on Gold Products")
plt.ylabel("Probabilities of less than Gold products spending values")
plt.show()

# %% [markdown]
# Probabilities increases sharply before stabilising near 100

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# **1 - Relationship between education status and amount spent on different products**

# %%
# segmentation of customers on the basis of education

sns.countplot(x=superstore_df.Education)
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Most of our customers are only graduate followed by PHDs, Masters , 2nd cycle and Basic

# %%
figure,axes = plt.subplots(2,2,figsize=(15,8))

sns.barplot(x=superstore_df.Education , y = superstore_df.MntWines, ax = axes[0,0])
sns.barplot(x=superstore_df.Education , y = superstore_df.MntFruits, ax = axes[0,1])
sns.barplot(x=superstore_df.Education , y = superstore_df.MntMeatProducts, ax = axes[1,0])
sns.barplot(x=superstore_df.Education , y = superstore_df.MntFishProducts, ax = axes[1,1])
axes[0,0].set_title('Average Amount Spent on Wines vs Education Status')
axes[0,0].set_xlabel("Education Status")
axes[0,0].set_ylabel("Average Amount Spent on Wines")
axes[0,1].set_title('Average Amount Spent on Fruits vs Education Status')
axes[0,1].set_xlabel("Education Status")
axes[0,1].set_ylabel("Average Amount Spent on Fruits")
axes[1,0].set_title('Average Amount Spent on Meat Products vs Education Status')
axes[1,0].set_xlabel("Education Status")
axes[1,0].set_ylabel("Average Amount Spent on Meat Products")
axes[1,1].set_title('Average Amount Spent on Fish Products vs Education Status')
axes[1,1].set_xlabel("Education Status")
axes[1,1].set_ylabel("Average Amount Spent on Fish Products")
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
figure,axes = plt.subplots(1,2,figsize=(12,5))

sns.barplot(x=superstore_df.Education , y = superstore_df.MntSweetProducts, ax = axes[0])
sns.barplot(x=superstore_df.Education , y = superstore_df.MntGoldProds, ax = axes[1])

axes[0].set_title('Average Amount Spent on Sweet Products vs Education Status')
axes[0].set_xlabel("Education Status")
axes[0].set_ylabel("Average Amount Spent on Sweet Products")
axes[1].set_title('Average Amount Spent on Gold Products vs Education Status')
axes[1].set_xlabel("Education Status")
axes[1].set_ylabel("Average Amount Spent on Gold Products")

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# **Insights**
#
# Customers with graduation tends to spend more on products of each type and customers with basic education spends the least among all . Customers with high education status like PHDs and masters tend to spend more on expensive products like wine and meat products

# %% [markdown]
# **2 - Relationship between marital status and amount spent on different products**

# %%
# segmentation of customers on the basis of marital status

sns.countplot(x=superstore_df.Marital_Status)
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Most of our customers are married followed by non married couples, single , divorced and widow

# %%
figure,axes = plt.subplots(2,2,figsize=(15,8))


sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntWines, ax = axes[0,0])
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntFruits, ax = axes[0,1])
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntMeatProducts, ax = axes[1,0])
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntFishProducts, ax = axes[1,1])
axes[0,0].set_title('Average Amount Spent on Wines vs Marital Status')
axes[0,0].set_xlabel("Marital Status")
axes[0,0].set_ylabel("Average Amount Spent on Wines")
axes[0,1].set_title('Average Amount Spent on Fruits vs Marital Status')
axes[0,1].set_xlabel("Marital Status")
axes[0,1].set_ylabel("Average Amount Spent on Fruits")
axes[1,0].set_title('Average Amount Spent on Meat Products vs Marital Status')
axes[1,0].set_xlabel("Marital Status")
axes[1,0].set_ylabel("Average Amount Spent on Meat Products")
axes[1,1].set_title('Average Amount Spent on Fish Products vs Marital Status')
axes[1,1].set_xlabel("Marital Status")
axes[1,1].set_ylabel("Average Amount Spent on Fish Products")
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
figure,axes = plt.subplots(1,2,figsize=(12,5))

sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntSweetProducts, ax = axes[0])
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntGoldProds, ax = axes[1])

axes[0].set_title('Average Amount Spent on Sweet Products vs Marital Status')
axes[0].set_xlabel("Marital Status")
axes[0].set_ylabel("Average Amount Spent on Sweet Products")
axes[1].set_title('Average Amount Spent on Gold Products vs Marital Status')
axes[1].set_xlabel("Marital Status")
axes[1].set_ylabel("Average Amount Spent on Gold Products")

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# **Insights**
#
# Spending habits of customers with different marital status are almost the same but widowed ones tends to spend more than others as can be seen in the above graphs

# %% [markdown]
# **3 - Relationship between age and amount spent on different products**

# %%
# creating a new column age group to better understand customer behaviour
conditions = [(superstore_df["age"]>20) & (superstore_df["age"]<=35),
              (superstore_df["age"]>35) & (superstore_df["age"]<=50),
              (superstore_df["age"]>50) & (superstore_df["age"]<=65),
              (superstore_df["age"]>65) & (superstore_df["age"]<=85)
              ]

values = ["20-35" , "35-50" , "50-65" , "65-85"]

superstore_df["Age_Group"] = np.select(conditions,values)

superstore_df["Age_Group"].value_counts()
# Out:
# 50-65    737
# 35-50    689
# 65-85    386
# 20-35     93
# Name: Age_Group, dtype: int64

# %%
# segmentation of customers on the basis of age

sns.countplot(x=superstore_df.Age_Group)
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# Most of our customers are in the age group of 50-65 followed by 35-60, 65-85 and 20-35

# %%
figure,axes = plt.subplots(2,2,figsize=(15,8))


sns.barplot(x=superstore_df.Age_Group , y = superstore_df.MntWines, ax = axes[0,0])
sns.barplot(x=superstore_df.Age_Group , y = superstore_df.MntFruits, ax = axes[0,1])
sns.barplot(x=superstore_df.Age_Group , y = superstore_df.MntMeatProducts, ax = axes[1,0])
sns.barplot(x=superstore_df.Age_Group , y = superstore_df.MntFishProducts, ax = axes[1,1])
axes[0,0].set_title('Average Amount Spent on Wines vs Age_Group')
axes[0,0].set_xlabel("Age_Group")
axes[0,0].set_ylabel("Average Amount Spent on Wines")
axes[0,1].set_title('Average Amount Spent on Fruits vs Age_Group')
axes[0,1].set_xlabel("Age_Group")
axes[0,1].set_ylabel("Average Amount Spent on Fruits")
axes[1,0].set_title('Average Amount Spent on Meat Products vs Age_Group')
axes[1,0].set_xlabel("Age_Group")
axes[1,0].set_ylabel("Average Amount Spent on Meat Products")
axes[1,1].set_title('Average Amount Spent on Fish Products vs Age_Group')
axes[1,1].set_xlabel("Age_Group")
axes[1,1].set_ylabel("Average Amount Spent on Fish Products")
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
figure,axes = plt.subplots(1,2,figsize=(12,5))

sns.barplot(x=superstore_df.Age_Group , y = superstore_df.MntSweetProducts, ax = axes[0])
sns.barplot(x=superstore_df.Age_Group , y = superstore_df.MntGoldProds, ax = axes[1])

axes[0].set_title('Average Amount Spent on Sweet Products vs Age_Group')
axes[0].set_xlabel("Age_Group")
axes[0].set_ylabel("Average Amount Spent on Sweet Products")
axes[1].set_title('Average Amount Spent on Gold Products vs Age_Group')
axes[1].set_xlabel("Age_Group")
axes[1].set_ylabel("Average Amount Spent on Gold Products")

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# **Insights**
#
# Customers in both end of the age spectrum tends to spend more than the others.
# 20-35 and 65-85 age range customers spends more than the other customers

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %% [markdown]
# Some visualizations are presented in the previous task . We will make some more visualizations here and make recommendations to the company on the basis of these.

# %%
# graph to show spending behaviour of customers of different educational backgrounds with their age group
figure,axes = plt.subplots(2,2,figsize=(15,8))

sns.barplot(x=superstore_df.Education , y = superstore_df.MntWines, ax = axes[0,0], hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Education , y = superstore_df.MntFruits, ax = axes[0,1] , hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Education , y = superstore_df.MntMeatProducts, ax = axes[1,0] , hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Education , y = superstore_df.MntFishProducts, ax = axes[1,1] , hue = superstore_df.Age_Group)
axes[0,0].set_title('Average Amount Spent on Wines vs Education Status')
axes[0,0].set_xlabel("Education Status")
axes[0,0].set_ylabel("Average Amount Spent on Wines")
axes[0,1].set_title('Average Amount Spent on Fruits vs Education Status')
axes[0,1].set_xlabel("Education Status")
axes[0,1].set_ylabel("Average Amount Spent on Fruits")
axes[1,0].set_title('Average Amount Spent on Meat Products vs Education Status')
axes[1,0].set_xlabel("Education Status")
axes[1,0].set_ylabel("Average Amount Spent on Meat Products")
axes[1,1].set_title('Average Amount Spent on Fish Products vs Education Status')
axes[1,1].set_xlabel("Education Status")
axes[1,1].set_ylabel("Average Amount Spent on Fish Products")
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
# graph to show spending behaviour of customers of different educational backgrounds with their marital status
figure,axes = plt.subplots(2,2,figsize=(15,8))

sns.barplot(x=superstore_df.Education , y = superstore_df.MntWines, ax = axes[0,0], hue = superstore_df.Marital_Status)
sns.barplot(x=superstore_df.Education , y = superstore_df.MntFruits, ax = axes[0,1] , hue = superstore_df.Marital_Status)
sns.barplot(x=superstore_df.Education , y = superstore_df.MntMeatProducts, ax = axes[1,0] , hue = superstore_df.Marital_Status)
sns.barplot(x=superstore_df.Education , y = superstore_df.MntFishProducts, ax = axes[1,1] , hue = superstore_df.Marital_Status)
axes[0,0].set_title('Average Amount Spent on Wines vs Education Status')
axes[0,0].set_xlabel("Education Status")
axes[0,0].set_ylabel("Average Amount Spent on Wines")
axes[0,1].set_title('Average Amount Spent on Fruits vs Education Status')
axes[0,1].set_xlabel("Education Status")
axes[0,1].set_ylabel("Average Amount Spent on Fruits")
axes[1,0].set_title('Average Amount Spent on Meat Products vs Education Status')
axes[1,0].set_xlabel("Education Status")
axes[1,0].set_ylabel("Average Amount Spent on Meat Products")
axes[1,1].set_title('Average Amount Spent on Fish Products vs Education Status')
axes[1,1].set_xlabel("Education Status")
axes[1,1].set_ylabel("Average Amount Spent on Fish Products")
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %% [markdown]
# **Recommendations on the Basis of Educational Qualifications**
#
# 1 - Company's marketing strategies should be mostly directed at the customers with graduation as they tend to spend more.
#
# 2 - PHDs and post graduates should be marketed with high price products as they spend more on them
#
# 3 - It should largely ignore basically educated customers as they spend less and whatever they spend, they spend on low price products
#
# 4 - PHDs in the age group of 20-35 are avid spenders as seen in above graph and our company should target them as potential customers
#
# 5 - 2nd cycle educated customers who are widowed are potential customers as they have high spending habits

# %%
# graph to show spending behaviour of customers of different marital status with their age
figure,axes = plt.subplots(2,2,figsize=(15,8))


sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntWines, ax = axes[0,0], hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntFruits, ax = axes[0,1] , hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntMeatProducts, ax = axes[1,0] , hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntFishProducts, ax = axes[1,1] , hue = superstore_df.Age_Group)
axes[0,0].set_title('Average Amount Spent on Wines vs Marital Status')
axes[0,0].set_xlabel("Marital Status")
axes[0,0].set_ylabel("Average Amount Spent on Wines")
axes[0,1].set_title('Average Amount Spent on Fruits vs Marital Status')
axes[0,1].set_xlabel("Marital Status")
axes[0,1].set_ylabel("Average Amount Spent on Fruits")
axes[1,0].set_title('Average Amount Spent on Meat Products vs Marital Status')
axes[1,0].set_xlabel("Marital Status")
axes[1,0].set_ylabel("Average Amount Spent on Meat Products")
axes[1,1].set_title('Average Amount Spent on Fish Products vs Marital Status')
axes[1,1].set_xlabel("Marital Status")
axes[1,1].set_ylabel("Average Amount Spent on Fish Products")
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
figure,axes = plt.subplots(1,2,figsize=(12,5))

sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntSweetProducts, ax = axes[0], hue = superstore_df.Age_Group)
sns.barplot(x=superstore_df.Marital_Status , y = superstore_df.MntGoldProds, ax = axes[1] , hue = superstore_df.Age_Group)

axes[0].set_title('Average Amount Spent on Sweet Products vs Marital Status')
axes[0].set_xlabel("Marital Status")
axes[0].set_ylabel("Average Amount Spent on Sweet Products")
axes[1].set_title('Average Amount Spent on Gold Products vs Marital Status')
axes[1].set_xlabel("Marital Status")
axes[1].set_ylabel("Average Amount Spent on Gold Products")

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# **Recommendations on the Basis of Marital Status**
#
# 1 - Widowed individuals have high spending tendencies in otherwise almost equal spending behaviour among different marital status customers
#
# 2 - Divorced individuals in the age group of 20-35 should be ignored as they hardly spent anything
#
# 3 - Customers with partners without getting married in the age group of 20-35 spends more so they should be offered special services.
#
# 4 - Married individuals in the age group of 65-85 spends a lot on wines so they should be targeted for wine buys
#
# 5 - Widowed individuals in the age group of 35-50 spend more on sweet and grold products . Company should see them as potential buyers

# %% [markdown]
# **Recommendations on the Basis of Age Group**
#
# 1 - 65-85 age group individuals spend more on products than others so they should be seen as potential customers
#
# 2 - 35-50 age group customers should be largely ignored in marketing stategies as they spend less than other age groups
#
# All other recommendations based on age groups are covered in previous sections

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
